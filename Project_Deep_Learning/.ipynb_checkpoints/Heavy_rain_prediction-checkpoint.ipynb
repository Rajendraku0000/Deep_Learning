# %%
import numpy as np

import pandas as pd

df=pd.read_csv("C:\\Users\\rajen\\OneDrive\\Desktop\\data\\HeavyRain.csv")

df.head()
# Out:
#    Unnamed: 0        date  month  day  previous_rainfall   rainfall
# 0           0  2022-01-01      1    1          54.881350  50.106317
# 1           1  2022-01-02      1    2          71.518937  37.638916
# 2           2  2022-01-03      1    3          60.276338  36.491184
# 3           3  2022-01-04      1    4          54.488318  26.090450
# 4           4  2022-01-05      1    5          42.365480  49.597030

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
mn=MinMaxScaler()

# %%
df[["month","day","previous_rainfall","rainfall"]]=mn.fit_transform(df[["month","day","previous_rainfall","rainfall"]])

df.head()
# Out:
#    Unnamed: 0        date  month       day  previous_rainfall  rainfall
# 0           0  2022-01-01    0.0  0.000000           0.547987  0.500887
# 1           1  2022-01-02    0.0  0.033333           0.714935  0.376121
# 2           2  2022-01-03    0.0  0.066667           0.602123  0.364635
# 3           3  2022-01-04    0.0  0.100000           0.544043  0.260551
# 4           4  2022-01-05    0.0  0.133333           0.422398  0.495790

# %%
df=df.drop(columns=["Unnamed: 0","date"])

# %%
x=df[["month","day","previous_rainfall"]].values
print(x.ndim)
x
# Out:
# 2
# array([[0.        , 0.        , 0.54798727],
#        [0.        , 0.03333333, 0.71493496],
#        [0.        , 0.06666667, 0.60212256],
#        ...,
#        [1.        , 0.93333333, 0.98802976],
#        [1.        , 0.96666667, 0.75917959],
#        [1.        , 1.        , 0.36308506]])

# %%
y=df["rainfall"].values
print(y.ndim)
y
# Out:
# 1
# array([5.00886555e-01, 3.76120537e-01, 3.64634748e-01, 2.60550661e-01,
#        4.95789919e-01, 6.81696654e-01, 2.76998561e-01, 5.24220399e-01,
#        1.16920545e-01, 1.59416874e-01, 4.62945268e-02, 9.70901408e-01,
#        3.31683240e-03, 1.78165380e-01, 6.12772639e-01, 8.08832762e-02,
#        8.82000914e-01, 7.19604820e-01, 9.66556733e-01, 5.07463779e-01,
#        3.00078993e-01, 5.49359698e-01, 9.30959229e-01, 5.20599355e-01,
#        2.66857844e-01, 8.77499881e-01, 3.71646831e-01, 8.38003034e-04,
#        2.47321429e-01, 3.17921976e-01, 8.58864819e-01, 4.58295143e-01,
#        4.44368995e-01, 3.35803919e-01, 8.80781635e-01, 9.45177774e-01,
#        9.92075908e-01, 3.76472908e-01, 9.66314028e-01, 7.91917554e-01,
#        6.75641392e-01, 2.44523823e-01, 2.16070624e-01, 1.65623989e-01,
#        9.22891173e-01, 2.93747303e-01, 4.52882230e-01, 4.93775973e-01,
#        7.78199465e-01, 8.44311581e-01, 1.38628959e-01, 4.26673018e-01,
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x
# Out:
# array([[0.        , 0.        , 0.54798727],
#        [0.        , 0.03333333, 0.71493496],
#        [0.        , 0.06666667, 0.60212256],
#        ...,
#        [1.        , 0.93333333, 0.98802976],
#        [1.        , 0.96666667, 0.75917959],
#        [1.        , 1.        , 0.36308506]])

# %%
y
# Out:
# array([5.00886555e-01, 3.76120537e-01, 3.64634748e-01, 2.60550661e-01,
#        4.95789919e-01, 6.81696654e-01, 2.76998561e-01, 5.24220399e-01,
#        1.16920545e-01, 1.59416874e-01, 4.62945268e-02, 9.70901408e-01,
#        3.31683240e-03, 1.78165380e-01, 6.12772639e-01, 8.08832762e-02,
#        8.82000914e-01, 7.19604820e-01, 9.66556733e-01, 5.07463779e-01,
#        3.00078993e-01, 5.49359698e-01, 9.30959229e-01, 5.20599355e-01,
#        2.66857844e-01, 8.77499881e-01, 3.71646831e-01, 8.38003034e-04,
#        2.47321429e-01, 3.17921976e-01, 8.58864819e-01, 4.58295143e-01,
#        4.44368995e-01, 3.35803919e-01, 8.80781635e-01, 9.45177774e-01,
#        9.92075908e-01, 3.76472908e-01, 9.66314028e-01, 7.91917554e-01,
#        6.75641392e-01, 2.44523823e-01, 2.16070624e-01, 1.65623989e-01,
#        9.22891173e-01, 2.93747303e-01, 4.52882230e-01, 4.93775973e-01,
#        7.78199465e-01, 8.44311581e-01, 1.38628959e-01, 4.26673018e-01,
# ...

# %%
import tensorflow as tf

# %%
from tensorflow import keras

# %%
from keras.models import Sequential

# %%
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(64,activation="relu",input_shape=(x_train.shape[1],)))
model.add(Dense(32,activation="relu"))
model.add(Dense(1,activation="linear"))

# %%
model.compile(optimizer="adam",loss="mean_squared_error",metrics=["accuracy"])

# %%
model.fit(x_train,y_train,epochs=10,batch_size=10,verbose=1)
# Out:
# Epoch 1/10
# 59/59 [==============================] - 1s 3ms/step - loss: 0.0890 - accuracy: 0.0017
# Epoch 2/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0888 - accuracy: 0.0000e+00
# Epoch 3/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0877 - accuracy: 0.0000e+00
# Epoch 4/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.0862 - accuracy: 0.0000e+00
# Epoch 5/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.0858 - accuracy: 0.0000e+00
# Epoch 6/10
# 59/59 [==============================] - 0s 3ms/step - loss: 0.0860 - accuracy: 0.0000e+00
# Epoch 7/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.0852 - accuracy: 0.0000e+00
# Epoch 8/10
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0858 - accuracy: 0.0000e+00
# Epoch 9/10
# 59/59 [==============================] - 0s 4ms/step - loss: 0.0855 - accuracy: 0.0000e+00
# Epoch 10/10
# ...

# %%
y_pred=model.predict(x_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,accuracy_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.09481955472856465

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.26569972661063385

# %%
accuracy_score(y_test,y_pred,normalize=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 accuracy_score(y_test,y_pred,normalize=False)
#
# File ~\anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
# --> 192     return func(*args, **kwargs)
#     193 except InvalidParameterError as e:
#     194     # When the function is just a wrapper around an estimator, we allow
#     195     # the function to delegate validation to the estimator, but we replace
#     196     # the name of the estimator by the name of the function in the error
#     197     # message to avoid confusion.
#     198     msg = re.sub(
# ...
